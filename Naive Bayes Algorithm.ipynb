# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('datasets/Social_Network_Ads.csv')
ds=dataset.drop('User ID',axis=1)
X = ds.iloc[:, [2, 3]].values
y = ds.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
ds=ds.drop('Gender',axis=1)

# %%
ds
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
columns=list(ds)
columns
# Out:
# ['Age', 'EstimatedSalary', 'Purchased']

# %%
len(ds)
# Out:
# 400

# %%
user=[20,30000]

# %%
data_arr=[]
dist_arr=[]
for i in range(400):
  for j in columns:
    print(ds[j][i])
    elem=ds[j][i]
    data_arr.append(elem)
  print(data_arr)
  dist=((user[0]-data_arr[0])**2 + (user[1]-data_arr[1])**2)**0.5
  dist_arr.append(dist)
  data_arr=[]
# Out:
# 19
# 19000
# 0
# [19, 19000, 0]
# 35
# 20000
# 0
# [35, 20000, 0]
# 26
# 43000
# 0
# [26, 43000, 0]
# 27
# 57000
# 0
# [27, 57000, 0]
# 19
# 76000
# 0
# [19, 76000, 0]
# 27
# 58000
# 0
# [27, 58000, 0]
# 27
# 84000
# 0
# [27, 84000, 0]
# 32
# 150000
# 1
# [32, 150000, 1]
# 25
# 33000
# 0
# [25, 33000, 0]
# 35
# 65000
# 0
# [35, 65000, 0]
# 26
# 80000
# 0
# [26, 80000, 0]
# 26
# 52000
# 0
# [26, 52000, 0]
# 20
# 86000
# 0
# [20, 86000, 0]
# 32
# 18000
# 0
# [32, 18000, 0]
# 18
# 82000
# 0
# [18, 82000, 0]
# 29
# 80000
# 0
# [29, 80000, 0]
# 47
# 25000
# 1
# [47, 25000, 1]
# 45
# 26000
# 1
# [45, 26000, 1]
# 46
# 28000
# 1
# [46, 28000, 1]
# 48
# 29000
# 1
# [48, 29000, 1]
# 45
# 22000
# 1
# [45, 22000, 1]
# 47
# 49000
# 1
# [47, 49000, 1]
# 48
# 41000
# 1
# [48, 41000, 1]
# 45
# 22000
# 1
# [45, 22000, 1]
# 46
# 23000
# 1
# [46, 23000, 1]
# 47
# 20000
# 1
# [47, 20000, 1]
# 49
# 28000
# 1
# [49, 28000, 1]
# 47
# 30000
# 1
# [47, 30000, 1]
# 29
# 43000
# 0
# [29, 43000, 0]
# 31
# ...

# %%
dist_arr
# Out:
# [11000.000045454546,
#  10000.011249993671,
#  13000.00138461531,
#  27000.000907407393,
#  46000.00001086957,
#  28000.000874999987,
#  54000.0004537037,
#  120000.0006,
#  3000.004166663773,
#  35000.00321428556,
#  50000.00036,
#  22000.000818181805,
#  56000.0,
#  12000.0059999985,
#  52000.00003846154,
#  50000.00080999999,
#  5000.072899468567,
#  4000.0781242370754,
#  2000.1689928603532,
#  1000.3919231981034,
#  8000.039062404633,
#  19000.019184200843,
#  11000.03563630591,
#  8000.039062404633,
#  7000.04828554775,
#  10000.03644993357,
#  2000.210238949896,
#  27.0,
#  13000.003115384243,
#  12000.005041665607,
#  44000.00137499998,
#  107000.00022897196,
#  14000.000035714285,
#  14000.0022857141,
#  60000.00040833333,
#  3000.037499765628,
#  2000.0422495537439,
#  19000.002631578765,
#  42000.000428571424,
#  1000.0244996998823,
#  13000.001884615249,
#  21000.00402380914,
#  78000.00144230768,
#  15000.003333332963,
#  54000.00059259259,
#  10000.00044999999,
# ...

# %%
result=ds

# %%
result['Age']=dataset['Age']
result['EstimatedSalary']=dataset['EstimatedSalary']
result['will purchase']=dataset['Purchased']

# %%
result
# Out:
#      Age  EstimatedSalary  Purchased  will purchase
# 0     19            19000          0              0
# 1     35            20000          0              0
# 2     26            43000          0              0
# 3     27            57000          0              0
# 4     19            76000          0              0
# ..   ...              ...        ...            ...
# 395   46            41000          1              1
# 396   51            23000          1              1
# 397   50            20000          1              1
# 398   36            33000          0              0
# 399   49            36000          1              1
#
# [400 rows x 4 columns]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
#  3   will purchase    400 non-null    int64
# dtypes: int64(4)
# memory usage: 12.6 KB

# %%
# view frequency counts of values in categorical variables

for var in ds: 
    
    print(ds[var].value_counts())
# Out:
# 35    32
# 37    20
# 26    16
# 41    16
# 42    16
# 39    15
# 40    15
# 48    14
# 47    14
# 27    13
# 38    13
# 28    12
# 36    12
# 46    12
# 31    11
# 30    11
# 49    10
# 29    10
# 33     9
# 32     9
# 24     9
# 59     7
# 19     7
# 45     7
# 20     7
# 60     7
# 34     6
# 23     6
# 52     6
# 25     6
# 58     6
# 53     5
# 57     5
# 22     5
# 18     5
# 21     4
# 50     4
# 54     4
# 55     3
# 56     3
# 51     3
# 43     3
# 44     2
# Name: Age, dtype: int64
# 72000     12
# 80000     11
# 79000     10
# 75000      9
# 71000      9
#           ..
# 123000     1
# 37000      1
# 115000     1
# 148000     1
# 139000     1
# Name: EstimatedSalary, Length: 117, dtype: int64
# 0    257
# 1    143
# Name: Purchased, dtype: int64
# 0    257
# 1    143
# Name: will purchase, dtype: int64

# %%
# view frequency distribution of categorical variables

for var in ds: 
    
    print(ds[var].value_counts()/np.float(len(ds)))
# Out:
# 35    0.0800
# 37    0.0500
# 26    0.0400
# 41    0.0400
# 42    0.0400
# 39    0.0375
# 40    0.0375
# 48    0.0350
# 47    0.0350
# 27    0.0325
# 38    0.0325
# 28    0.0300
# 36    0.0300
# 46    0.0300
# 31    0.0275
# 30    0.0275
# 49    0.0250
# 29    0.0250
# 33    0.0225
# 32    0.0225
# 24    0.0225
# 59    0.0175
# 19    0.0175
# 45    0.0175
# 20    0.0175
# 60    0.0175
# 34    0.0150
# 23    0.0150
# 52    0.0150
# 25    0.0150
# 58    0.0150
# 53    0.0125
# 57    0.0125
# 22    0.0125
# 18    0.0125
# 21    0.0100
# 50    0.0100
# 54    0.0100
# 55    0.0075
# 56    0.0075
# 51    0.0075
# 43    0.0075
# 44    0.0050
# Name: Age, dtype: float64
# 72000     0.0300
# 80000     0.0275
# 79000     0.0250
# 75000     0.0225
# 71000     0.0225
#            ...
# 123000    0.0025
# 37000     0.0025
# 115000    0.0025
# 148000    0.0025
# 139000    0.0025
# Name: EstimatedSalary, Length: 117, dtype: float64
# 0    0.6425
# 1    0.3575
# Name: Purchased, dtype: float64
# ...

# %%
#for naive bayes algorithm  we have to import gaussiannb
from sklearn.naive_bayes import GaussianNB
nv = GaussianNB()

# %%
nv.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = nv.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.83

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pred,y_test)
# Out:
# array([[66, 15],
#        [ 2, 17]], dtype=int64)

# %%
# Print the Confusion Matrix and slice it into four pieces

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print('Confusion matrix\n\n', cm)
print('\nTrue Positives(TP) = ', cm[0,0])
print('\nTrue Negatives(TN) = ', cm[1,1])
print('\nFalse Positives(FP) = ', cm[0,1])
print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[66  2]
#  [15 17]]
#
# True Positives(TP) =  66
#
# True Negatives(TN) =  17
#
# False Positives(FP) =  2
#
# False Negatives(FN) =  15

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.81      0.89        81
#            1       0.53      0.89      0.67        19
#
#     accuracy                           0.83       100
#    macro avg       0.75      0.85      0.78       100
# weighted avg       0.89      0.83      0.84       100

# %%
import seaborn as sns

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], 
                                 index=['Predict Positive:1', 'Predict Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <AxesSubplot: >
